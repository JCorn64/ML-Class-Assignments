# %% [markdown]
# # Assignment 4: Benchmarking Neural Nets with the XOR Problem

# %% [markdown]
# ### CS 4774 Machine Learning - Department of Computer Science - University of Virginia
# In this assignment, you will implement your own neural networks to classify non-linear data from the XOR dataset. For references, you may refer to my [lecture 10](https://docs.google.com/presentation/d/1otQfmMomWctLZKI3hHKAA4lLkbXFtagLaQov8gNh4LI/edit?usp=sharing) and [Colab Notebook 10](https://colab.research.google.com/drive/1x5biI3dP5YvvDEI0wapJcSgQNnATDzNe) if you need additional sample codes to help with your assignment. For deliverables, you must write code in Python/Tensorflow and submit **this** Jupyter Notebook file (.ipynb) to earn a total of 100 pts. Note that you must save your Notebook filename under this format: **yourUvaUserId_assignment_4_ann.ipynb**.

# %%
# You might want to use the following packages
import numpy as np
import os
# %tensorflow_version 2.x
import tensorflow as tf

from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from functools import partial

# %% [markdown]
# ---
# ## 1. THE DATASET AND VISUALIZATION
#
# We will use the non-linear toy data called the XOR dataset. You may use the code snippet below to generate the train/validate/test set. Feel free to change the number of samples, and noise level. To keep the ratio between the sets consistent, please do not change the test_size and random_state parameters.

# %%
def make_xor(n_points):
    centers = np.array([[0,0],[0,1],[1,0],[1,1]])
    labels = np.array([0,1,1,0])
    data = np.array([]).reshape(-1,3)
    for center, label in zip(centers,labels):
        points = np.random.normal(loc=center,scale=0.2,size=(n_points//4,2))
        points_labels = np.hstack((points,label*np.ones(n_points//4).reshape((-1, 1))))
        data = np.vstack((data,points_labels))
    return (data[:,[0,1]],data[:,2])


X, y = make_xor(1000)
y=y.astype(np.int64)
X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=0.2, random_state=49)
X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size= 0.1, random_state=49) 
print(X_train.shape)
print(X_test.shape)
print(X_val.shape)
plt.scatter(X[:,0], X[:,1], s=40, c=y, cmap=plt.cm.Spectral)
# Out:
# (720, 2)
# (200, 2)
# (80, 2)

# %% [markdown]
# ---
# ## 2. TRAIN A SIMPLE ANN FOR CLASSIFICATION TASK (20 pts)
#
# Use the standard libarary of Neural Net on the training data, and then test the classifier on the test data. You will create a simple ANN with 3 layers: an Input Layer, a Hidden Layer and an Output Layer. For each layer, you can specify the number of nodes appropriate for the XOR problem. Also, feel free to tune the network as you see fit. You have to report the accuracy of the network on the validation set.

# %%
from tensorflow import keras

model = keras.models.Sequential()

model.add(keras.layers.InputLayer(2))
model.add(keras.layers.Dense(100, activation='tanh'))
model.add(keras.layers.Dense(2, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])

# %% [markdown]
# for every row in a2:
#   add log to sum of a[i][y[i]]
# (take avg of this sum)

# %% [markdown]
# - - -
# ## 3. IMPLEMENTING YOUR OWN SIMPLE NEURAL NETWORK (60 pts)
#
# Now that you see how the standard library ANN performs on the XOR dataset, you will attempt to implement your own version of the neural network. To help you, a template has been created including the backpropagation. Essensially, you will get the backward gradients for free. However, please note that the backprop implementation assume usage of tanh activation for the hidden layer and softmax for the output layer. There are some subtasks which you need to implement in order to get the network to work properly.

# %%
from sklearn.base import BaseEstimator
import math

class MyNeuralNet(BaseEstimator):
    """Your implementation of a simple neural network"""

    def __init__ (self, nn_input_dim, nn_hidden_dim, nn_output_dim):
        """
        Initialize the network with random weights

        @param: nn_input_dim: Number of nodes in the input layer
        @param: nn_hidden_dim: Number of nodes in the hidden layer
        @param: nn_output_dim: Number of nodes in the output layer
        """
        # SUBTASK 1 (10 pts): Initialize the parameters to random values.
        np.random.seed(49)
        self.W1 = np.random.randn(nn_input_dim, nn_hidden_dim)
        self.b1 = np.zeros(shape=(1, nn_hidden_dim))
        self.W2 = np.random.randn(nn_hidden_dim, nn_output_dim)
        self.b2 = np.zeros(shape=(1, nn_output_dim))
        
    def loss(self, X, y):
        """
        Evaluate the average loss on the dataset
        """

        # Forward propagation will be needed to calculate the loss
        a1,a2 = self.forward_pass(X)
        # SUBTASK 2 (10 pts): Calculate the loss using log-loss probabilities using a2.
        # You will need to return the average loss on the data 
        data_loss = 0
        for i in range(len(y)):
          data_loss += -y[i] * math.log(a2[i,y[i]])
        data_loss = data_loss/len(y)
        return data_loss

    def forward_pass(self, X):
        """
        Pass the signal forward through the layers.
        @param: X: feature
        @return: a1: saved value of the output of the hidden layer
        @return: a2: activated return value of the output layer.
        """
        # SUBTASK 3 (20 pts): Implement Forward propagation.
        # Note that you must implement tanh activiation for the hiden layer, and softmax for the output layer
        z1 = X.dot(self.W1)+self.b1
        a1 = np.tanh(z1)
        z2 = np.dot(a1, self.W2)+self.b2
        a2 = np.exp(z2)/np.sum(np.exp(z2), axis=1, keepdims=True)
        return a1, a2 

    def backward_pass(self,a1,a2,X,y):
        """
        Pass the signal back and compute the gradient

        @param: X: feature
        @param: y: label
        @param: a1: saved value of the output of the hidden layer
        @param: a2: activated return value of the output layer.

        @return: dW1: the gradient of W1
        @return: db1: the gradient of b1
        @return: dW2: the gradient of W2
        @return: db2: the gradient of b2
        """
        # You do not have to change this function, ...
        # unless you are advanced and want to use different activation function.
        m = len(y) # number of example
        delta2 = a2
        y.astype(np.int64)
        delta2[range(m), y] -= 1
        dW2 = (a1.T).dot(delta2)
        db2 = np.sum(delta2, axis=0, keepdims=True)
        delta1 = delta2.dot(self.W2.T) * (1 - np.power(a1, 2))
        dW1 = np.dot(X.T, delta1)
        db1 = np.sum(delta1, axis=0)
        return dW1, db1, dW2, db2

    def fit(self, X, y, epochs, alpha, X_val, y_val):
        """
        Learns parameters for the neural network and returns the model.
        
        @param: X: the training feature
        @param: y: the train label
        @param: epochs: Number of passes through the training data for gradient descent
        @param: X_val: the feature of validation set
        @param: y_val: the label of validation set
        """

        # Gradient descent. For each batch...
        for i in range(0, epochs):

            # Forward pass
            a1,a2 = self.forward_pass(X);

            # Backpropagation
            dW1, db1, dW2, db2 = self.backward_pass(a1,a2,X,y)

            # SUBTASK 4 (10 pts): Compute the gradient descent parameter update

            self.W1 = self.W1 - alpha * dW1
            self.b1 = self.b1 - alpha * db1
            self.W2 = self.W2 - alpha * dW2
            self.b2 = self.b2 - alpha * db2
        
            # Print the loss and validation accuracy at current epoch.
            if i % 10 == 0:
                print("Epoch %i/%i - loss: %f - accuracy: %f - val_loss: %f - val_acc: %f" 
                      %(i,epochs, self.loss(X_train, y_train), self.evaluate(X_train, y_train),
                        self.loss(X_val, y_val), self.evaluate(X_val,y_val)))


    def evaluate(self, X, y):
        """
        Evaluate the accuracy of the model
        """
        y_pred = self.predict(X)
        return sum(y_pred == y)/len(y)

    def predict(self, X):
        """
        Predict an output

        @param: X: feature
        @return: y_pred: predicted label (0 or 1)
        """
        # SUBTASK 5 (10 pts): Implement the prediction process. 
        # Hint: It should include a forward pass, and then use the class with higher probability.
        a1, a2 = self.forward_pass(X)
        y_pred = []
        for y,x in a2:
          if y > x:
            y_pred.append(0)
          else:
            y_pred.append(1)

        return np.array(y_pred)


    def plot_decision_boundary(self, pred_func):
        """
        Plot a decision boundary for visualization purpose.
        If you don't fully understand this function don't worry, it just generates the contour plot below.
        """
        # Set min and max values and give it some padding
        x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
        y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
        h = 0.01
        # Generate a grid of points with distance h between them
        xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
        # Predict the function value for the whole gid
        Z = pred_func(np.c_[xx.ravel(), yy.ravel()])
        Z = Z.reshape(xx.shape)
        # Plot the contour and training examples
        plt.contourf(xx, yy, Z, cmap=plt.cm.Pastel1)
        plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Spectral)

# %% [markdown]
# ---
# ## 4. REFLECT ON THE COMPARISON BETWEEN YOUR IMPLEMENTATION TO THE STANDARD LIBRARY (20 pts)
# Now that you have implemented your own Neural Net class, let's use it! Create at least 3 instances of your Neural Net class, each with a different number of nodes in the hiden layer, tune it with the appropriate learning rate and number of iteration. You will test their performance in the Xor dataset and report the test accuracy metrics for each instance of your neural network.
#
# Based on the test accuracy, compare your models with the standard library version.

# %%
# MODEL 1: Some hyperparameters are provided, but feel free to change them.
nn_input_dim = 2 # input layer dimensionality
nn_output_dim = 2 # output layer dimensionality
nn_hidden_dim = 50 # hiden layer dimensionality
alpha = 0.001 # learning rate for gradient descent
epochs = 200 # number of iteration/epochs
# Build a model with 3 layer
myModel1 = MyNeuralNet(nn_input_dim, nn_hidden_dim, nn_output_dim);
myModel1.fit(X_train, y_train, epochs, alpha, X_val, y_val)

# Plot the decision boundary
myModel1.plot_decision_boundary(lambda x: myModel1.predict(x))
# See the weights and biases of the network
print(myModel1.W1)
print(myModel1.b1)
print(myModel1.W2)
print(myModel1.b2)
# Out:
# Epoch 0/200 - loss: 0.000000 - accuracy: 0.486111 - val_loss: 0.000000 - val_acc: 0.587500
# Epoch 10/200 - loss: 0.022433 - accuracy: 0.984722 - val_loss: 0.030612 - val_acc: 0.975000
# Epoch 20/200 - loss: 0.020882 - accuracy: 0.987500 - val_loss: 0.028530 - val_acc: 0.975000
# Epoch 30/200 - loss: 0.019923 - accuracy: 0.987500 - val_loss: 0.026454 - val_acc: 0.975000
# Epoch 40/200 - loss: 0.019139 - accuracy: 0.987500 - val_loss: 0.024722 - val_acc: 0.975000
# Epoch 50/200 - loss: 0.018493 - accuracy: 0.987500 - val_loss: 0.023335 - val_acc: 0.975000
# Epoch 60/200 - loss: 0.017949 - accuracy: 0.987500 - val_loss: 0.022199 - val_acc: 0.975000
# Epoch 70/200 - loss: 0.017482 - accuracy: 0.987500 - val_loss: 0.021246 - val_acc: 0.975000
# Epoch 80/200 - loss: 0.017074 - accuracy: 0.987500 - val_loss: 0.020429 - val_acc: 0.975000
# Epoch 90/200 - loss: 0.016713 - accuracy: 0.987500 - val_loss: 0.019719 - val_acc: 0.975000
# Epoch 100/200 - loss: 0.016392 - accuracy: 0.987500 - val_loss: 0.019093 - val_acc: 0.975000
# Epoch 110/200 - loss: 0.016103 - accuracy: 0.987500 - val_loss: 0.018536 - val_acc: 0.975000
# Epoch 120/200 - loss: 0.015841 - accuracy: 0.987500 - val_loss: 0.018036 - val_acc: 0.975000
# Epoch 130/200 - loss: 0.015603 - accuracy: 0.987500 - val_loss: 0.017584 - val_acc: 0.975000
# Epoch 140/200 - loss: 0.015386 - accuracy: 0.987500 - val_loss: 0.017174 - val_acc: 0.975000
#  [ 1.45233948 -0.78421356]
#  [ 0.32839947  0.42960588]
#  [ 0.96194592  0.01827499]
#  [ 0.48638918  0.62569841]
#  [ 0.39238119 -1.38799973]
#  [-0.65072788  1.68103299]
#  [-0.44656944 -0.10502287]
#  [ 0.26953444 -2.27835097]
#  [ 0.94235433 -1.00780799]
#  [-0.35713731 -0.48962019]
#  [ 0.68749425  0.4744458 ]
#  [ 0.46056852  0.14151747]
#  [-0.24349393  0.11092897]
#  [-1.59857137  1.35784897]
#  [-0.08876991 -0.7901364 ]
#  [-0.56335342  0.16502405]
#  [ 0.88929736  0.37230456]
#  [ 1.73731695 -1.64376787]
#  [-0.54729886 -0.17502549]
#  [-0.55427418 -0.77912622]
#  [-0.30128733  1.73709874]
#  [-0.27190091 -0.46408792]
#  [ 1.8927681  -1.63906405]
#  [ 0.02998925 -0.57214735]
#  [-0.83906628  0.51867754]
#  [-0.80441056  0.78831663]
#  [-0.23345241 -0.60716865]
#  [-0.84690939  2.4959141 ]
#  [-0.21445015  0.49831336]
#  [-2.55228106  1.4599185 ]
#  [ 1.72588164  1.08909811]
#  [ 0.08792379 -0.07383358]
#  [ 1.20544743 -1.53478973]
#  [ 0.15498994  0.20182241]]
# [[-0.04090056  0.04090056]]

# %%
# MODEL 2 here

nn_input_dim = 2 # input layer dimensionality
nn_output_dim = 2 # output layer dimensionality
nn_hidden_dim = 6 # hiden layer dimensionality
alpha = 0.0001 # learning rate for gradient descent
epochs = 200 # number of iteration/epochs
# Build a model with 3 layer
myModel1 = MyNeuralNet(nn_input_dim, nn_hidden_dim, nn_output_dim);
myModel1.fit(X_train, y_train, epochs, alpha, X_val, y_val)

# Plot the decision boundary
myModel1.plot_decision_boundary(lambda x: myModel1.predict(x))
# See the weights and biases of the network
print(myModel1.W1)
print(myModel1.b1)
print(myModel1.W2)
print(myModel1.b2)
# Out:
# Epoch 0/200 - loss: 0.300590 - accuracy: 0.575000 - val_loss: 0.350984 - val_acc: 0.600000
# Epoch 10/200 - loss: 0.292231 - accuracy: 0.806944 - val_loss: 0.347586 - val_acc: 0.812500
# Epoch 20/200 - loss: 0.280334 - accuracy: 0.923611 - val_loss: 0.337773 - val_acc: 0.887500
# Epoch 30/200 - loss: 0.268500 - accuracy: 0.950000 - val_loss: 0.326729 - val_acc: 0.950000
# Epoch 40/200 - loss: 0.257400 - accuracy: 0.972222 - val_loss: 0.315834 - val_acc: 0.950000
# Epoch 50/200 - loss: 0.246995 - accuracy: 0.981944 - val_loss: 0.305368 - val_acc: 0.962500
# Epoch 60/200 - loss: 0.237165 - accuracy: 0.983333 - val_loss: 0.295351 - val_acc: 0.975000
# Epoch 70/200 - loss: 0.227832 - accuracy: 0.986111 - val_loss: 0.285759 - val_acc: 0.975000
# Epoch 80/200 - loss: 0.218949 - accuracy: 0.986111 - val_loss: 0.276561 - val_acc: 0.962500
# Epoch 90/200 - loss: 0.210487 - accuracy: 0.986111 - val_loss: 0.267725 - val_acc: 0.962500
# Epoch 100/200 - loss: 0.202421 - accuracy: 0.987500 - val_loss: 0.259225 - val_acc: 0.962500
# Epoch 110/200 - loss: 0.194732 - accuracy: 0.986111 - val_loss: 0.251036 - val_acc: 0.950000
# Epoch 120/200 - loss: 0.187401 - accuracy: 0.986111 - val_loss: 0.243141 - val_acc: 0.950000
# Epoch 130/200 - loss: 0.180410 - accuracy: 0.984722 - val_loss: 0.235527 - val_acc: 0.950000
# Epoch 140/200 - loss: 0.173746 - accuracy: 0.984722 - val_loss: 0.228187 - val_acc: 0.950000
# Epoch 150/200 - loss: 0.167396 - accuracy: 0.984722 - val_loss: 0.221114 - val_acc: 0.950000
# Epoch 160/200 - loss: 0.161349 - accuracy: 0.984722 - val_loss: 0.214307 - val_acc: 0.950000
# Epoch 170/200 - loss: 0.155592 - accuracy: 0.984722 - val_loss: 0.207762 - val_acc: 0.950000
# Epoch 180/200 - loss: 0.150115 - accuracy: 0.984722 - val_loss: 0.201476 - val_acc: 0.950000
# Epoch 190/200 - loss: 0.144907 - accuracy: 0.984722 - val_loss: 0.195445 - val_acc: 0.950000
# [[-1.56692157 -0.85884921  0.69318992  2.01495068 -1.36028881  0.11333931]
#  [ 0.79744967  0.24045924 -0.05142834  2.03690375  1.94200125 -0.33307338]]
# [[-0.29771895  0.00927973 -0.03345538 -0.37657757  0.63748624  0.00913991]]
# [[-0.93643548  1.05867193]
#  [-1.23922134 -0.89875129]
#  [ 1.19752585  0.89245983]
#  [-0.78985861  1.5251041 ]
#  [-0.46195283 -2.39604906]
#  [-0.21574889  0.36263914]]
# [[-0.11947883  0.11947883]]

# %%
# MODEL 3

nn_input_dim = 2 # input layer dimensionality
nn_output_dim = 2 # output layer dimensionality
nn_hidden_dim = 100 # hiden layer dimensionality
alpha = 0.003 # learning rate for gradient descent
epochs = 400 # number of iteration/epochs
# Build a model with 3 layer
myModel1 = MyNeuralNet(nn_input_dim, nn_hidden_dim, nn_output_dim);
myModel1.fit(X_train, y_train, epochs, alpha, X_val, y_val)

# Plot the decision boundary
myModel1.plot_decision_boundary(lambda x: myModel1.predict(x))
# See the weights and biases of the network
print(myModel1.W1)
print(myModel1.b1)
print(myModel1.W2)
print(myModel1.b2)
# Out:
# Epoch 0/400 - loss: 7.188795 - accuracy: 0.741667 - val_loss: 10.218636 - val_acc: 0.625000
# Epoch 10/400 - loss: 2.275026 - accuracy: 0.731944 - val_loss: 3.537133 - val_acc: 0.637500
# Epoch 20/400 - loss: 0.022052 - accuracy: 0.988889 - val_loss: 0.069760 - val_acc: 0.950000
# Epoch 30/400 - loss: 0.016970 - accuracy: 0.988889 - val_loss: 0.037447 - val_acc: 0.950000
# Epoch 40/400 - loss: 0.013482 - accuracy: 0.988889 - val_loss: 0.014394 - val_acc: 0.950000
# Epoch 50/400 - loss: 0.011594 - accuracy: 0.988889 - val_loss: 0.005635 - val_acc: 0.962500
# Epoch 60/400 - loss: 0.010997 - accuracy: 0.986111 - val_loss: 0.003880 - val_acc: 0.962500
# Epoch 70/400 - loss: 0.010773 - accuracy: 0.987500 - val_loss: 0.003497 - val_acc: 0.962500
# Epoch 80/400 - loss: 0.010620 - accuracy: 0.987500 - val_loss: 0.003434 - val_acc: 0.962500
# Epoch 90/400 - loss: 0.010484 - accuracy: 0.988889 - val_loss: 0.003506 - val_acc: 0.962500
# Epoch 100/400 - loss: 0.010360 - accuracy: 0.988889 - val_loss: 0.003668 - val_acc: 0.962500
#  [-8.66634661e-02 -3.09461991e-01]
#  [-1.68214063e-01 -8.80994334e-02]
#  [ 1.58383214e-02 -6.37523953e-02]
#  [ 6.94063854e-01 -5.77965294e-01]
#  [ 1.88888820e+00 -1.56260176e+00]
#  [-2.18001996e-01  7.25284650e-01]
#  [ 1.05480719e+00  9.87944762e-01]
#  [-7.75093594e-01  1.10078868e+00]
#  [ 1.09985908e+00 -1.29379946e+00]
#  [ 1.91066688e+00 -7.29131706e-01]
#  [-7.59229547e-01 -8.90295332e-01]
#  [-3.33790677e-01 -5.60810190e-01]
#  [ 1.41942728e+00 -7.95401851e-02]
#  [ 2.65586350e-01  2.72027252e-01]
#  [-1.31931385e-01 -1.54779563e-01]
#  [-2.14593929e-03 -8.40482943e-01]
#  [-1.04089970e+00 -1.17421710e+00]]
# [[-0.30361549  0.30361549]]

# %%
# STANDARD MODEL

model.fit(X_train, y_train, epochs=200)
model.evaluate(X_test, y_test)
# Out:
# Epoch 1/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.7005 - accuracy: 0.4611
# Epoch 2/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6993 - accuracy: 0.5194
# Epoch 3/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6974 - accuracy: 0.4778
# Epoch 4/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6963 - accuracy: 0.6847
# Epoch 5/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6955 - accuracy: 0.6250
# Epoch 6/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6950 - accuracy: 0.6736
# Epoch 7/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6943 - accuracy: 0.6153
# Epoch 8/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6942 - accuracy: 0.6153
# Epoch 9/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6933 - accuracy: 0.5583
# Epoch 10/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6929 - accuracy: 0.5833
# Epoch 11/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6924 - accuracy: 0.5208
# Epoch 12/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6927 - accuracy: 0.4194
# Epoch 13/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6925 - accuracy: 0.4264
# Epoch 14/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6922 - accuracy: 0.4556
# Epoch 15/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6921 - accuracy: 0.3736
# Epoch 16/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6919 - accuracy: 0.3347
# Epoch 17/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6915 - accuracy: 0.4083
# Epoch 18/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6916 - accuracy: 0.5028
# Epoch 19/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6913 - accuracy: 0.4764
# Epoch 20/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6911 - accuracy: 0.4014
# Epoch 21/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6913 - accuracy: 0.4083
# Epoch 22/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6909 - accuracy: 0.4514
# Epoch 23/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6912 - accuracy: 0.4861
# Epoch 24/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6909 - accuracy: 0.5097
# Epoch 25/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6905 - accuracy: 0.5097
# Epoch 26/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6906 - accuracy: 0.4319
# Epoch 27/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6905 - accuracy: 0.4972
# Epoch 28/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6906 - accuracy: 0.5528
# Epoch 29/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6904 - accuracy: 0.5125
# Epoch 30/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6903 - accuracy: 0.5528
# Epoch 31/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6899 - accuracy: 0.4958
# Epoch 32/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6898 - accuracy: 0.4958
# Epoch 33/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6897 - accuracy: 0.5306
# Epoch 34/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6893 - accuracy: 0.5181
# Epoch 35/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6894 - accuracy: 0.5542
# Epoch 36/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6895 - accuracy: 0.5319
# Epoch 37/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6891 - accuracy: 0.5153
# Epoch 38/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6891 - accuracy: 0.5042
# Epoch 39/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6893 - accuracy: 0.5736
# Epoch 40/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6892 - accuracy: 0.5694
# Epoch 41/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6885 - accuracy: 0.5778
# Epoch 42/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6890 - accuracy: 0.5167
# Epoch 43/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6885 - accuracy: 0.5486
# Epoch 44/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6878 - accuracy: 0.5736
# Epoch 45/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6878 - accuracy: 0.5500
# Epoch 46/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6881 - accuracy: 0.6125
# Epoch 47/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6878 - accuracy: 0.5083
# Epoch 48/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6876 - accuracy: 0.5667
# Epoch 49/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6876 - accuracy: 0.5208
# Epoch 50/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6867 - accuracy: 0.5417
# Epoch 51/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6872 - accuracy: 0.5181
# Epoch 52/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6868 - accuracy: 0.5444
# Epoch 53/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6869 - accuracy: 0.6361
# Epoch 54/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6866 - accuracy: 0.5944
# Epoch 55/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6863 - accuracy: 0.5889
# Epoch 56/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6862 - accuracy: 0.4847
# Epoch 57/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6857 - accuracy: 0.5319
# Epoch 58/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6860 - accuracy: 0.5875
# Epoch 59/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6853 - accuracy: 0.5708
# Epoch 60/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6855 - accuracy: 0.5958
# Epoch 61/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6849 - accuracy: 0.5875
# Epoch 62/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6848 - accuracy: 0.5708
# Epoch 63/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6844 - accuracy: 0.5958
# Epoch 64/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6842 - accuracy: 0.6111
# Epoch 65/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6838 - accuracy: 0.6264
# Epoch 66/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6839 - accuracy: 0.6000
# Epoch 67/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6839 - accuracy: 0.6083
# Epoch 68/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6834 - accuracy: 0.6042
# Epoch 69/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6831 - accuracy: 0.6361
# Epoch 70/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6829 - accuracy: 0.6347
# Epoch 71/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6826 - accuracy: 0.5292
# Epoch 72/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6823 - accuracy: 0.5556
# Epoch 73/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6813 - accuracy: 0.6097
# Epoch 74/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6816 - accuracy: 0.5264
# Epoch 75/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6811 - accuracy: 0.6097
# Epoch 76/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6810 - accuracy: 0.5833
# Epoch 77/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6810 - accuracy: 0.6306
# Epoch 78/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6803 - accuracy: 0.6139
# Epoch 79/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6794 - accuracy: 0.6375
# Epoch 80/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6799 - accuracy: 0.6694
# Epoch 81/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6793 - accuracy: 0.6472
# Epoch 82/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6786 - accuracy: 0.6153
# Epoch 83/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6783 - accuracy: 0.6222
# Epoch 84/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6778 - accuracy: 0.6319
# Epoch 85/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6773 - accuracy: 0.5472
# Epoch 86/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6771 - accuracy: 0.6000
# Epoch 87/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6765 - accuracy: 0.5764
# Epoch 88/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6758 - accuracy: 0.6931
# Epoch 89/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6755 - accuracy: 0.6486
# Epoch 90/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6749 - accuracy: 0.6278
# Epoch 91/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6741 - accuracy: 0.6389
# Epoch 92/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6741 - accuracy: 0.6361
# Epoch 93/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6735 - accuracy: 0.6236
# Epoch 94/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6724 - accuracy: 0.6097
# Epoch 95/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6715 - accuracy: 0.7069
# Epoch 96/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6711 - accuracy: 0.6111
# Epoch 97/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6702 - accuracy: 0.6861
# Epoch 98/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6695 - accuracy: 0.6625
# Epoch 99/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6691 - accuracy: 0.6264
# Epoch 100/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6682 - accuracy: 0.7125
# Epoch 101/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6681 - accuracy: 0.6167
# Epoch 102/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6669 - accuracy: 0.6681
# Epoch 103/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6660 - accuracy: 0.6556
# Epoch 104/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6657 - accuracy: 0.6972
# Epoch 105/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6640 - accuracy: 0.6667
# Epoch 106/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6637 - accuracy: 0.7000
# Epoch 107/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6636 - accuracy: 0.6625
# Epoch 108/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6624 - accuracy: 0.6583
# Epoch 109/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6609 - accuracy: 0.7111
# Epoch 110/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6602 - accuracy: 0.7097
# Epoch 111/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6591 - accuracy: 0.7014
# Epoch 112/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6578 - accuracy: 0.7361
# Epoch 113/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6568 - accuracy: 0.7389
# Epoch 114/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6562 - accuracy: 0.7250
# Epoch 115/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6551 - accuracy: 0.7125
# Epoch 116/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6538 - accuracy: 0.7139
# Epoch 117/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6525 - accuracy: 0.7472
# Epoch 118/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6512 - accuracy: 0.7792
# Epoch 119/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6501 - accuracy: 0.7667
# Epoch 120/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6487 - accuracy: 0.8028
# Epoch 121/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6474 - accuracy: 0.8194
# Epoch 122/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6459 - accuracy: 0.7903
# Epoch 123/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6450 - accuracy: 0.8042
# Epoch 124/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6430 - accuracy: 0.8347
# Epoch 125/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6413 - accuracy: 0.8556
# Epoch 126/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6404 - accuracy: 0.8361
# Epoch 127/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6383 - accuracy: 0.8472
# Epoch 128/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6372 - accuracy: 0.8528
# Epoch 129/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6357 - accuracy: 0.8500
# Epoch 130/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6340 - accuracy: 0.8681
# Epoch 131/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6323 - accuracy: 0.8722
# Epoch 132/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6309 - accuracy: 0.8833
# Epoch 133/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6285 - accuracy: 0.8833
# Epoch 134/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6270 - accuracy: 0.8681
# Epoch 135/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6244 - accuracy: 0.9000
# Epoch 136/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6230 - accuracy: 0.8986
# Epoch 137/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6212 - accuracy: 0.8917
# Epoch 138/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6196 - accuracy: 0.8806
# Epoch 139/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6175 - accuracy: 0.8972
# Epoch 140/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6151 - accuracy: 0.8958
# Epoch 141/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6130 - accuracy: 0.8944
# Epoch 142/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6109 - accuracy: 0.8694
# Epoch 143/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6089 - accuracy: 0.8986
# Epoch 144/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6060 - accuracy: 0.8972
# Epoch 145/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6049 - accuracy: 0.9194
# Epoch 146/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6017 - accuracy: 0.9167
# Epoch 147/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5996 - accuracy: 0.9333
# Epoch 148/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5972 - accuracy: 0.8986
# Epoch 149/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5943 - accuracy: 0.9014
# Epoch 150/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5916 - accuracy: 0.9208
# Epoch 151/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5896 - accuracy: 0.9153
# Epoch 152/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5871 - accuracy: 0.9250
# Epoch 153/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5847 - accuracy: 0.9278
# Epoch 154/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5817 - accuracy: 0.9167
# Epoch 155/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5790 - accuracy: 0.9264
# Epoch 156/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5753 - accuracy: 0.9208
# Epoch 157/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5734 - accuracy: 0.9208
# Epoch 158/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5703 - accuracy: 0.9194
# Epoch 159/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5667 - accuracy: 0.9208
# Epoch 160/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5644 - accuracy: 0.9236
# Epoch 161/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5620 - accuracy: 0.9222
# Epoch 162/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5588 - accuracy: 0.9222
# Epoch 163/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5547 - accuracy: 0.9208
# Epoch 164/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5525 - accuracy: 0.9194
# Epoch 165/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5498 - accuracy: 0.9375
# Epoch 166/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5455 - accuracy: 0.9292
# Epoch 167/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5438 - accuracy: 0.9306
# Epoch 168/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5403 - accuracy: 0.9319
# Epoch 169/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5356 - accuracy: 0.9333
# Epoch 170/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5339 - accuracy: 0.9278
# Epoch 171/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5317 - accuracy: 0.9222
# Epoch 172/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5276 - accuracy: 0.9347
# Epoch 173/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5230 - accuracy: 0.9375
# Epoch 174/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5195 - accuracy: 0.9361
# Epoch 175/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5170 - accuracy: 0.9403
# Epoch 176/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5140 - accuracy: 0.9417
# Epoch 177/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5102 - accuracy: 0.9306
# Epoch 178/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5067 - accuracy: 0.9306
# Epoch 179/200
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5032 - accuracy: 0.9403
# Epoch 180/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4996 - accuracy: 0.9278
# Epoch 181/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4959 - accuracy: 0.9431
# Epoch 182/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4935 - accuracy: 0.9375
# Epoch 183/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4889 - accuracy: 0.9389
# Epoch 184/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4867 - accuracy: 0.9319
# Epoch 185/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4827 - accuracy: 0.9431
# Epoch 186/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4808 - accuracy: 0.9444
# Epoch 187/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4757 - accuracy: 0.9333
# Epoch 188/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4732 - accuracy: 0.9403
# Epoch 189/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4690 - accuracy: 0.9375
# Epoch 190/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4666 - accuracy: 0.9472
# Epoch 191/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4622 - accuracy: 0.9444
# Epoch 192/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4586 - accuracy: 0.9458
# Epoch 193/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4552 - accuracy: 0.9431
# Epoch 194/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4526 - accuracy: 0.9431
# Epoch 195/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4497 - accuracy: 0.9458
# Epoch 196/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4455 - accuracy: 0.9431
# Epoch 197/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4422 - accuracy: 0.9389
# Epoch 198/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4375 - accuracy: 0.9500
# Epoch 199/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4356 - accuracy: 0.9472
# Epoch 200/200
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4326 - accuracy: 0.9458
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4492 - accuracy: 0.9300
# [0.44921383261680603, 0.9300000071525574]

# %% [markdown]
# ## Reflection
# Write at least a paragraph answering these prompts: How did your own network perform? Is there any major differences between the implementations? Finally, reflecting on your experience implementing a learning algorithm for this assignment (Was it hard/easy/fun?, From which part did you learn the most?)!

# %%
'''
Overall my own Network performed really well, the highest accuracy I achieved was .99167 wich did better than the standard library which had an accuracy of 0.9300. 
This was probably because I tweaked the epochs and learning rate which allowed for the higher accuracy. In general in terms of the implemenmtation I can see as to why 
keras is widely used for beggining model creation, simply just adding layers together like a lego and choosing what each ones does. The implementation of the NN we 
created ourselves did not take too much code in terms of lines, but the logic that went behind it was confusiong at times to undertsand and/or follow. I think though while frusterating at times
it was cool to see how all of the systems came together for the final NN to work. 
'''

# %% [markdown]
# ---
# # Get Help?
# In case you get stuck in any step in the process, you may find some useful information from:
#
#  * Consult my [lecture 10](https://docs.google.com/presentation/d/1otQfmMomWctLZKI3hHKAA4lLkbXFtagLaQov8gNh4LI/edit?usp=sharing) and [Colab Notebook 10](https://colab.research.google.com/drive/1x5biI3dP5YvvDEI0wapJcSgQNnATDzNe)
#  * Talk to the TA, they are available and there to help you during office hour.
#  * Come talk to me or email me <nn4pj@virginia.edu> with subject starting "CS4774 Assignment 4:...".
#
# Part of the codes used in this assignment is modified from Konstantinos Kitsios under the 3-Clause BSD License. Best of luck and have fun!
